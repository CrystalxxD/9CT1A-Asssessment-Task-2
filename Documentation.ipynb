# %% [markdown]
# # Documentation
# ## Identifying and Defining
# Data: Description of the data you are looking to analyse.
#
# Change in price of cars as newer models of the car comes out
#
# <br> Goal: Explanation of what you want to find out using the data.
#
# Seeing if the cars get more expensive or less expensive as the car model gets newer
#
# <br> Source: Link to the source of your data.
#
# Source is https://www.kaggle.com/datasets/waqi786/cars-dataset-2010-2020
#
# <br> Access: Identification of whether the data is publicly available or not.
#
# Its assessable for anyone
#
# <br> Access Method: How you will access the data (.csv or API)
#
# CSV file
#
# ### Functional Requirements
# #### Data Loading: Consider aspects such as ability to load certain file types and handling errors in file loading (e.g. incorrect format, missing files).
#
# Description: The program needs to be able to pull data from files of different formats: . csv, Excel, or JSON. It should also be able to deal with errors such as the wrong format of the file, the file is missing or the availability of the wrong type of file.
#
# Input: The basic file format could be either CSV Excel or JSON.
#
# Output: Transferred data in a structured format such as the data structures in Python like Pandas
#
# #### <br> Data Cleaning: Does the system need to handle missing values or allow for filtering, sorting and grouping of data?
#
# Description: Some of the real-time data preparation methodologies that should be applied to the program include deleting missing values, screening records, ordering the data by the model’s year, and clustering by the car’s model when necessary. It should be able to deal and report with duplicates and inconsistent records.
#
# Input: Raw data (Pandas DataFrame) Cleaning steps (e.g. Empty the missing values or how it is done with duplicates).Selecting and segregating factors (for instance, by the model of cars, by the year of manufacture).
#
# Output: Data cleaning and structuring (cleaned up data in pandas data frame format )
#
# #### <br> Data Analysis: What kind of statistical analysis does the system need to allow for (e.g. mean, median, mode)?
#
# Description: The program should accommodate statistical analysis concerning pricing trends of cars over some time. This might include how to arrive at an average price for each model year, the highest and the lowest prices and more to that, trends in the prices of the models.
#
# Input: Cleaned data (Pandas DataFrame)
# Boilerplate parameters: design elements of the analysis (e.g., to compare, and calculate the average, the median, and the differences between prices for the same good in different years).
#
# Output: Test results, where the average price for a given model year or the change in the price is expressed in a number or a table or summary statistics of results such as mean price per type of model, rate of change of the price and the like.
#
# #### <br> Data Visualisation: How will the data need to be visualised (e.g. Pandas dataframes / Matplotlib chart types)?
#
# Description: The program should be able to plot the values in one or more charts like line charts to reflect the variation of prices based on time, a Bar chart to compare prices of different models and a scatter diagram to check the price distribution. It would be also logical to expect title customization, label customization, and legend customization.
#
# Input:
# Data to be analysed or to be used to plot chart (Name of the Pandas Series or DataFrame)
# Subtype of visualization, namely line chart for price movements and bar chart for price difference. Customization options
#
# Output:
# Visualization aspect of the information (for example creation of a line graph to depict price variation over some time). Exported the developed visualizations in the form of images
#
# #### <br> Data Reporting: What output should the system include, and do we need to store the final dataset somewhere (e.g. .csv or .txt file)?
#
#
# Description: Another required output is the preparation of a final report of the analysis conducted by the program. This comprises writing the cleaned and analyzed data to a file, for instance, a CSV file as well as saving the visualizations and a written report on the findings.
#
# Input:
# Analyzed data (Pandas DataFrame)
# Data format and organization of the report, as well as the extension for saving the file (CSV, Excel, .txt, etc. )
# FTP address, directory, or folder (for the report to be saved at)
#
# Output:
# A last document file, in the form of a .csv, an. xlsx, a . txt, or a similar file with the analyzed data.
# Account for retained graphics (for example, . png files).
# Overall the findings (For example, a . txt file containing the synthesis of the research and the recommendations).
# This outline can be useful while creating the system to draw the movement of car prices over time by prompting the development of all essential functions.
#
# ### Use Case
#
# Use cases essentially describe how users will interact with the system by providing an example of how it will work. The following example demonstrates how you create a use-case and the template should be used to create a use-case for each functional requirement.
#
# Actor: User
#
# Goal: To find the difference in price of a particular car
#
# Preconditions: User has a dataset file ready.
#
# Main Flow:
#
# &nbsp; &nbsp; 1. User places the dataset for reading into the correct folder.
#
# &nbsp; &nbsp; 2. System validates the file format.
#
# &nbsp; &nbsp; 3. System loads the dataset and displays the information in a dataframe.
#
# Postconditions: Dataset is loaded and ready for analysis.
#
#
# ### Non-Functional Requirements
# #### Usability: What is required from the User Interface and a 'README' document?
#
# Description: The layout of the application should be simple, the implementation of buttons and forms should be easy to learn and there should be hints on where to find what you need. The user interface should demonstrate how the data is loaded, how analysis is done and how results are displayed. It should also give the user real-time feedback and explain in detail any actions the user needs to take.
#
# Input: Clicks, selections and file uploads by users and their use of the Software and Systems. Analytical input of text, including the name of the files and special parameters to be used in the calculation.
#
# Output: The easy-to-use navigation provides clear instructions, asks and responses to enable even the less computer-literate persons to follow through with ease.
#
#
# #### <br> Reliability: What is required from the system when providing information to the user on errors and ensuring data integrity?
#
# Description: The author of the program should ensure that there is a rich ‘README’ file that can help the user know how to install the program, how to set it up and how to use it. The document will contain a set of instructions for further actions, a description of the program’s functions, recommendations in case of possible failures, and requirements for the system and other dependent applications.
#
# Input: Requests that involve the procedures of installing, configuring, operating, or addressing problems of a software product or system by users.
#
# Output: A clear and comprehensive ‘README’ file that contains solutions to most questions that may come along the users’ way and also assists the users to have an easy time using the software.

# %% [markdown]
# ## Researching and Planing
# ### Research of Chosen Issue
#
# #### Purpose: We've already looked at this a little, but let's clearly articulate what you're trying to find out and why it is important using further research.
#
# What I am trying to find out is the change in price of cars as newer models of the car comes out. This hleps people decide what model best suits them and if the car is good for its price
#
# #### <br> Missing Data: Explain why you feel it is necessary to carry out this analysis, with explicit reference to what the current data / information you have found is missing.
#
#
#
# #### <br> Stakeholders: Who will benefit from the information you create?
#
# People who wants new cars
#
# #### <br> Use: How can the information you obtain from this data analysis be used for or by those who benefit?
#
# To see the best price for the car models
#
# ## Privacy and Security
#
# #### Data Privacy of Source: Look at where you are sourcing your data. Outline the data that the source needs to protect and explain their responsibilities in protecting their participant's privacy.
#
# We collect information to provide better services to all our users. When you’re not signed into a Kaggle account, we store the information we collect with unique identifiers tied to the browser, application, or device you’re using. When you’re signed in, we collect information that we store with your Kaggle account.
#
#
# #### <br> Application Data Privacy: What are your responsibilities in maintaining user privacy in terms of this data? Is any data identifiable? Describe your responsibilities if you were to push this application out to the general public.
#
# The users data will have to be hidden and secure. My responsibilities will be to remove data that the users want to be deleted and to protect the data
#
# #### <br> Cyber Security: Research what features an application should have in order to maintain cybersecurity once it is available on the web. Explain the terms user authentication, password hashing and encryption.
#
# 2 step verification, data encryption, secure password.
#
# | Field | Datatype | Format for display | Description | Example | Validation |
# |:--------:|:--------:|:--------:|:--------:|:--------:|:--------:|
# |  Brand   |  object   |  XX...XX   |  Name of the company that made the car   |  Toyota   |  Any amount of characters but no numbers   |
# |  Model   |  object  |  XX...XX   |  Car model   |  Corolla   |  Any Character and number   |
# |  Year   |  datetime64   |  YYYY   |  Year car model was made   |  2024   |  Must be only year   |
# |  Engine Size (L)   |  float64   |  N.NN   |  How many litre the engine can hold   |  2.4   |  Must be numbers with one decimal place   |
# |  Fuel Type   |  object   |  XX...XX   |  what type of fuel does it use   |  Hybrid   |  Must be either Hybrid, Petrol or Electric   |
# |  Price (USD)   |   float64  |  N.NNNNNN   |  Price of car in USD   |  41643.75   |  Must be USD price   |
# |  Price (AUD)  |  float64   |  N.NNNNNN   |  Price of car in AUD   |  50678.29   |  Must be AUD price   |

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Added the price in AUD
new_dataframe = pd.read_csv('Data/cars_2010_2020.csv')
new_dataframe['Price (USD)'].astype(float) 
new_dataframe['Price (AUD)'] = new_dataframe['Price (USD)'].multiply(1.5)
new_dataframe = new_dataframe.astype({'Engine Size (L)':'float','Price (AUD)':'float'})
print(new_dataframe)
# Out:
#            Brand     Model  Year  Engine Size (L) Fuel Type  Price (USD)  \
# 0     Volkswagen     Jetta  2010              4.2    Petrol     54073.09
# 1          Honda     Pilot  2017              4.2    Hybrid     44924.91
# 2         Nissan    Murano  2011              4.2    Hybrid     76963.44
# 3         Toyota      RAV4  2010              2.4    Petrol     30871.25
# 4         Nissan    Altima  2010              3.6    Petrol     72037.65
# ...          ...       ...   ...              ...       ...          ...
# 9995         BMW  3 Series  2018              1.9    Hybrid     31676.02
# 9996     Hyundai    Sonata  2011              2.6    Diesel     67942.46
# 9997   Chevrolet    Impala  2011              1.3  Electric     64342.88
# 9998         BMW        X3  2020              1.4    Diesel     50060.30
# 9999   Chevrolet   Equinox  2018              2.7  Electric     53418.84
#
#       Price (AUD)
# 0       81109.635
# 1       67387.365
# 2      115445.160
# ...

# %%
# Words to search for
word_to_search = 'Toyota'

new_word_to_search = '2020'

new_new_word_to_search = 'Hybrid'

# Search for the word in the entire DataFrame
result = new_dataframe[new_dataframe.apply(lambda row: row.astype(str).str.contains(word_to_search).any(), axis=1)]

new_result = result[result.apply(lambda row: row.astype(str).str.contains(new_word_to_search).any(), axis=1)]

new_new_result = new_result[new_result.apply(lambda row: row.astype(str).str.contains(new_new_word_to_search).any(), axis=1)]

# Display the result
print(new_new_result)

# Graph
new_new_result.plot(
               kind='bar',
               x='Model',
               y='Price (AUD)',
               color='red',
               alpha=0.3,
               title='Price of Model in AUD'
              )
plt.show()
# Out:
#        Brand       Model  Year  Engine Size (L) Fuel Type  Price (USD)  \
# 244   Toyota        RAV4  2020              1.5    Hybrid     27285.97
# 308   Toyota  Highlander  2020              4.0    Hybrid     31269.16
# 428   Toyota        RAV4  2020              2.7    Hybrid     45098.27
# 651   Toyota     Corolla  2020              4.0    Hybrid     36892.09
# 746   Toyota       Camry  2020              1.4    Hybrid     29860.12
# 875   Toyota     Corolla  2020              3.7    Hybrid     42650.97
# 1075  Toyota     Corolla  2020              3.7    Hybrid     58234.09
# 1154  Toyota       Prius  2020              2.4    Hybrid     67506.98
# 2314  Toyota  Highlander  2020              4.6    Hybrid     45005.24
# 2604  Toyota        RAV4  2020              3.0    Hybrid     55283.90
# 3563  Toyota        RAV4  2020              1.2    Hybrid     16301.65
# 3947  Toyota        RAV4  2020              2.0    Hybrid     79065.83
# ...

# %% [markdown]
# ## Testing
# Nothing wrong with code works perfectly fine

# %% [markdown]
# ## Evaluation
# My time management throughout the task was great. The problem with my time was that I wasn't here for a week. For the testing part I conducted multiple test on all of the functions and there was no problems at all. Challanges I faced was making an AUD column. I overcame it by asking the teacher for a help and understanding what was wrong (the USD column wasn't float64)

# %% [markdown]
# ## Peer Evaluation
# Victor:
#
#
#
# Lewis:
